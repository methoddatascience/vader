# %%
from __future__ import print_function

import pandas as pd
pd.__version__
# Out:
# '0.22.0'

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
  name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-a0a93999-fa32-4ab1-a400-a6b7b25e482b" name="files[]" multiple disabled />
#      <output id="result-a0a93999-fa32-4ab1-a400-a6b7b25e482b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv
# User uploaded file "train.csv" with length 302133017 bytes

# %%
pd.read_csv('train.csv')
# Out:
#              ID_code  target    var_0   var_1    var_2    var_3    var_4  \
# 0            train_0       0   8.9255 -6.7863  11.9081   5.0930  11.4607
# 1            train_1       0  11.5006 -4.1473  13.8588   5.3890  12.3622
# 2            train_2       0   8.6093 -2.7457  12.0805   7.8928  10.5825
# 3            train_3       0  11.0604 -2.1518   8.9522   7.1957  12.5846
# 4            train_4       0   9.8369 -1.4834  12.8746   6.6375  12.2772
# 5            train_5       0  11.4763 -2.3182  12.6080   8.6264  10.9621
# 6            train_6       0  11.8091 -0.0832   9.3494   4.2916  11.1355
# 7            train_7       0  13.5580 -7.9881  13.8776   7.5985   8.6543
# 8            train_8       0  16.1071  2.4426  13.9307   5.6327   8.8014
# 9            train_9       0  12.5088  1.9743   8.8960   5.4508  13.6043
# 10          train_10       0   5.0702 -0.5447   9.5900   4.2987  12.3910
# 11          train_11       0  12.7188 -7.9750  10.3757   9.0101  12.8570
# ...

# %%
df = pd.read_csv('train.csv')
df.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
df.shape
# Out:
# (200000, 202)

# %%
df['target'].value_counts().plot.bar();

# %%
import matplotlib.pyplot as plt
f,ax=plt.subplots(1,2,figsize=(20,10))
df[df['target']==0].var_0.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('target= 0')
x1=list(range(0,85,5))
df[df['target']==1].var_0.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('target= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# Mean Frequency

# %%
df[df.columns[2:]].mean().plot('hist');plt.title('Mean Frequency');

# %% [markdown]
# the target in data set is imbalanced

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(9,7)})
sns.distplot(df['target']);
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
def check_missing_data(df):
    flag=df.isna().sum().any()
    if flag==True:
        total = df.isnull().sum()
        percent = (df.isnull().sum())/(df.isnull().count()*100)
        output = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
        data_type = []
        # written by MJ Bahmani
        for col in df.columns:
            dtype = str(df[col].dtype)
            data_type.append(dtype)
        output['Types'] = data_type
        return(np.transpose(output))
    else:
        return(False)

# %% [markdown]
# Checking missing data

# %%
check_missing_data(df)
# Out:
# False

# %% [markdown]
# Permutation Importance¶
#
#     What features have the biggest impact on predictions?
#     how to extract insights from models?

# %%
cols=["target","ID_code"]
X = df.drop(cols,axis=1)
y = df["target"]

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split

df_X, val_X, df_y, val_y = train_test_split(X, y, random_state=1)
rfc_model = RandomForestClassifier(random_state=0).fit(df_X, df_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# How to calculate and show importances?

# %%
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(rfc_model, random_state=1).fit(val_X, val_y)
eli5.show_weights(perm, feature_names = val_X.columns.tolist(), top=150)

# %% [markdown]
# Need to work on eli5 for this
